# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JH1GpEnhGRKjrWvHHtS2Tb-j1FmQmXS0eIKfVRa8VWCA")
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="hello"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 from google import genai
#       3 client = genai.Client(api_key="AQ.Ab8RN6JH1GpEnhGRKjrWvHHtS2Tb-j1FmQmXS0eIKfVRa8VWCA")
# ----> 4 response = client.models.generate_content(
#       5     model="gemini-2.0-flash",
#       6     contents="hello"
#       7 )
#       8 print(response.text)
#
# File c:\Users\smgam\anaconda3\Lib\site-packages\google\genai\models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# ...
